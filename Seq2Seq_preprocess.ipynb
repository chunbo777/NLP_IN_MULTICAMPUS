# %% [markdown]
# <a href="https://colab.research.google.com/github/chunbo777/chunbo777/blob/main/Seq2Seq_preprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp '/content/drive/MyDrive/preprocess.py' .

# %%
# !git clone https://github.com/NLP-kr/tensorflow-ml-nlp-tf2.git
# Out:
# Cloning into 'tensorflow-ml-nlp-tf2'...
# remote: Enumerating objects: 1715, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 1715 (delta 42), reused 9 (delta 5), pack-reused 1631
# Receiving objects: 100% (1715/1715), 201.17 MiB | 15.93 MiB/s, done.
# Resolving deltas: 100% (1032/1032), done.
# Checking out files: 100% (88/88), done.

# %%
# !cp -r '/content/tensorflow-ml-nlp-tf2/6.CHATBOT/data_in' .

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 54.0 MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 32.9 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 4.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
from preprocess import *

# %%
PATH = "data_in/ChatBotData.csv"
VOCAB_PATH = "data_in/vocabulary.txt"

# %%
inputs, outputs = load_data(PATH)

# %%
word2idx, idx2word, vocab_size = load_vocabulary(PATH, VOCAB_PATH, tokenize_as_morph=True)
# Out:
# 100%|██████████| 11823/11823 [00:21<00:00, 554.40it/s]
# 100%|██████████| 11823/11823 [00:12<00:00, 914.42it/s]

# %%
index_enc_inputs, enc_input_seq_len = enc_processing(inputs, word2idx, tokenize_as_morph=True)
index_dec_inputs, dec_input_seq_len = dec_input_processing(outputs, word2idx, tokenize_as_morph=True)
index_dec_targets = dec_target_processing(outputs, word2idx, tokenize_as_morph=True)
# Out:
# 100%|██████████| 11823/11823 [00:09<00:00, 1189.83it/s]
# 100%|██████████| 11823/11823 [00:12<00:00, 922.38it/s]
# 100%|██████████| 11823/11823 [00:12<00:00, 927.53it/s]

# %%
data_config = {}
data_config['word2idx'] = word2idx
data_config['idx2word'] = idx2word
data_config['vocab_size'] = vocab_size
data_config['pad_symbol'] = PAD
data_config['sos_symbol'] = SOS
data_config['eos_symbol'] = EOS
data_config['UNK_symbol'] = UNK

# %%
data_config
# Out:
# {'UNK_symbol': '<UNK>',
#  'eos_symbol': '<EOS>',
#  'idx2word': {0: '<PAD>',
#   1: '<SOS>',
#   2: '<EOS>',
#   3: '<UNK>',
#   4: '괜찮았었는데',
#   5: '최신',
#   6: '받니',
#   7: '어리석은',
#   8: '남이었나',
#   9: '우울하다',
#   10: '곱씹지',
#   11: '아프신',
#   12: '참으면',
#   13: '길게',
#   14: '먹으러',
#   15: '일까봐',
#   16: '그럼',
#   17: '보내는',
#   18: '설사',
#   19: '나와요',
#   20: '솔직해서',
#   21: '5',
#   22: '이었을테니까',
#   23: '걔',
#   24: '현명하시군요',
#   25: '멘탈',
#   26: '읽는다',
#   27: '떠보는',
#   28: '털털',
#   29: '처리',
#   30: '탈까',
#   31: '똑같이',
#   32: '오해',
#   33: '괜찮지만',
#   34: '초면',
#   35: '꾼',
#   36: '쌓였네',
#   37: '곱씹어도',
#   38: '하셨어요',
#   39: '동선',
#   40: '보냈군요',
#   41: '힘든고',
#   42: '귀염둥',
#   43: '상책',
#   44: '청결한',
#   45: '가르쳐',
#   46: '회',
#   47: '들도록',
#   48: '대단한',
#   49: '위로',
#   50: '캐',
#   51: '붙었대',
#   52: '파마',
#   53: '갔지',
#   54: '글귀',
#   55: '갈궈',
#   56: '쏠',
#   57: '힘든가요',
#   58: '아껴주세요',
#   59: '사과',
#   60: '타는데',
#   61: '비싸다',
#   62: '사니',
#   63: '400일',
#   64: '소홀히',
#   65: '당첨',
#   66: '요긴',
#   67: '싸는',
#   68: '지내고',
#   69: '멍하네',
#   70: '쏟아지고',
#   71: '궁금하니까',
#   72: '설레게하는',
#   73: '동갑',
#   74: '부담스러',
#   75: '풀',
#   76: '하는구나',
#   77: '사무칠',
#   78: '와야',
#   79: '수도',
#   80: '해바라기',
#   81: '부담스럽나',
#   82: '태그',
#   83: '날씨',
#   84: '찾아가는건',
#   85: '해서예요',
#   86: '바뀔까',
#   87: '맛있어',
#   88: '첫날',
#   89: '오려나',
#   90: '신의',
#   91: '코',
#   92: '상메',
#   93: '랑은',
#   94: '후회',
#   95: '땅',
#   96: '부었어',
#   97: '자르듯',
#   98: '턱',
#   99: '관문',
#   100: '바람',
#   101: '때매',
#   102: '거짓',
#   103: '보냈습니다',
#   104: '우울하고',
#   105: '보렵니',
#   106: '필요할테니',
#   107: '두꺼워',
#   108: '아니지요',
#   109: '했지만',
#   110: '주제',
#   111: '맞출까',
#   112: '먹구',
#   113: '해주고싶을',
#   114: '공연',
#   115: '맛없어',
#   116: '떨리겠어요',
#   117: '받는다고',
#   118: '두려운게',
#   119: '달라질까',
#   120: '애매한',
#   121: '가야겠죠',
#   122: '영원했으면',
#   123: '단답이나',
#   124: '되었지만',
#   125: '쿨하게',
#   126: '원하는걸',
#   127: '돌아와요',
#   128: '난뒤',
#   129: '큐피드',
#   130: '떨어요',
#   131: '감동',
#   132: '믿으세요',
#   133: '없애기',
#   134: '있었겠어요',
#   135: '느리겠죠',
#   136: '솔직하고',
#   137: '찢어지내',
#   138: '반복',
#   139: '맞추세요',
#   140: '없네',
#   141: '출근',
#   142: '잃어버림',
#   143: '아름답지',
#   144: '간단하게',
#   145: '자기애',
#   146: '챙겼어',
#   147: '간의',
#   148: '호팬',
#   149: '들어오네',
#   150: '마침표',
#   151: '갖춰서',
#   152: '괜찮으면',
#   153: '안좋겠지',
#   154: '인가요',
#   155: '뚫니는',
#   156: '귀찮아서',
#   157: '나오는',
#   158: '컴백',
#   159: '빌려',
#   160: '없을거예요',
#   161: '놓지',
#   162: '변했다고',
#   163: '넓으신',
#   164: '서른',
#   165: '가잖아',
#   166: '용납',
#   167: '보이스피싱',
#   168: '끝났는데',
#   169: '그러니',
#   170: '줄었어',
#   171: '달려있겠죠',
#   172: '떠났으면',
#   173: '짓게',
#   174: '장벽',
#   175: '도대체',
#   176: '알바',
#   177: '넣을',
#   178: '부추기면',
#   179: '지겠지',
#   180: '가네',
#   181: '트레이닝복',
#   182: '삶속',
#   183: '조심해야겠다',
#   184: '보여준것',
#   185: '재미있을',
#   186: '없든',
#   187: '스킨십',
#   188: '명절',
#   189: '재',
#   190: '외로울까',
#   191: '지나갔으면',
#   192: '없죠',
#   193: '일어났나',
#   194: '더보',
#   195: '추가',
#   196: '아쉽지만',
#   197: '이상해졌어',
#   198: '떨어져',
#   199: '일차',
#   200: '유지',
#   201: '잊혀질까',
#   202: '일방',
#   203: '화이트데이',
#   204: '귀여워',
#   205: '쓸쓸합니다',
#   206: '좋으면서도',
#   207: '심심',
#   208: '넘',
#   209: '겠지만',
#   210: '하자고',
#   211: '극혐',
#   212: '말껄',
#   213: '않은건',
#   214: '나쁘겠어요',
#   215: '째야',
#   216: '나아지고',
#   217: '아련하네요',
#   218: '아니겠지요',
#   219: '된다',
#   220: '에서까지',
#   221: '이기도',
#   222: '야구장',
#   223: '친절한',
#   224: '꾹꾹',
#   225: '인맥',
#   226: '선택',
#   227: '올거야',
#   228: '커지거나',
#   229: '광탈',
#   230: '쉬셔야',
#   231: '나타났을까요',
#   232: '안좋아요',
#   233: '농도',
#   234: '실례',
#   235: '지나고나면',
#   236: '타냐고',
#   237: '아련하기도',
#   238: '독박',
#   239: '무감각',
#   240: '애석해요',
#   241: '어때요',
#   242: '위험하겠지',
#   243: '잊어야겠지',
#   244: '하다',
#   245: '어리석게',
#   246: '맞아서',
#   247: '나가기도',
#   248: '찾아야',
#   249: '않아요',
#   250: '양제',
#   251: '온통',
#   252: '이었길',
#   253: '꾹',
#   254: '동거',
#   255: '확실하다면',
#   256: '보는게',
#   257: '한나',
#   258: '본지',
#   259: '달라져요',
#   260: '코골',
#   261: '씻기',
#   262: '대하는게',
#   263: '꽃',
#   264: '김치볶음밥',
#   265: '날거',
#   266: '되나',
#   267: '냉동',
#   268: '해보시는건',
#   269: '잊기로',
#   270: '내서',
#   271: '않습니다',
#   272: '블랙데이',
#   273: '생겼나',
#   274: '42일',
#   275: '편해',
#   276: '놓으세요',
#   277: '않지요',
#   278: '라는',
#   279: '나그네',
#   280: '육아',
#   281: '마셔야겠다',
#   282: '고충',
#   283: '구질',
#   284: '스타벅스',
#   285: '비싸겠지',
#   286: '안고',
#   287: '넓어',
#   288: '사오세요',
#   289: '해야하는',
#   290: '느껴지지',
#   291: '하고야',
#   292: 'ㅜ',
#   293: '신혼집',
#   294: '스타',
#   295: '보입니다',
#   296: '흘려도',
#   297: '여러',
#   298: '보여줘야',
#   299: '가미',
#   300: '가리세요',
#   301: '데',
#   302: '쓰담',
#   303: '힘내라는',
#   304: '쳐다봄',
#   305: '불효',
#   306: '돌릴',
#   307: '넘었는데도',
#   308: '명언',
#   309: '바라던',
#   310: '취뽀',
#   311: '받아들이',
#   312: '벌주어야',
#   313: '꽃다발',
#   314: '남으면',
#   315: '대기네요',
#   316: '당했어',
#   317: '자격지심',
#   318: '달렸나',
#   319: '키워',
#   320: '찍고',
#   321: '시켜야',
#   322: '보람',
#   323: '한정식',
#   324: '알아차리지',
#   325: '힘들줄',
#   326: '많을까요',
#   327: '갔을까',
#   328: '태',
#   329: '이루길',
#   330: '전과',
#   331: '듣고싶어',
#   332: '저녁',
#   333: '만났었지',
#   334: '느껴지겠어요',
#   335: '솔솔',
#   336: '걸레질',
#   337: '껴야겠어',
#   338: '드라이',
#   339: '질려하려면',
#   340: '하죠',
#   341: '헌신',
#   342: '있고싶다는',
#   343: '해라고',
#   344: '다크서클',
#   345: '쌓여가',
#   346: '망설여지나',
#   347: '갈림',
#   348: '봤으면',
#   349: '기대하면서',
#   350: '사귈래',
#   351: '끝',
#   352: '부부',
#   353: '가만히',
#   354: '애틋한',
#   355: '겟',
#   356: '생판',
#   357: '무사히',
#   358: '건강하게',
#   359: '쓴',
#   360: '쉬운게',
#   361: '화난',
#   362: '많았어요',
#   363: '다정다감한',
#   364: '감은',
#   365: '지나가지',
#   366: '낀',
#   367: '갈았어',
#   368: '의문',
#   369: '심하긴',
#   370: '넘고',
#   371: '갑작스러웠을테니까',
#   372: '살아야죠',
#   373: '익숙해졌나',
#   374: '좋아하게',
#   375: '쫙',
#   376: '붙이세요',
#   377: '할줄이야',
#   378: '분하고',
#   379: '헤어진',
#   380: '고고',
#   381: '다시는',
#   382: '짜증남',
#   383: '갠톡',
#   384: '돼야지',
#   385: '받아들여야',
#   386: '만날거야',
#   387: '됐던',
#   388: '라나',
#   389: '두절',
#   390: '님들',
#   391: '형',
#   392: '퐈',
#   393: '죽겠어',
#   394: '바랐지만',
#   395: '싸늘해',
#   396: '앉는',
#   397: '싶었나',
#   398: '쓰디',
#   399: '잊든',
#   400: '고시원',
#   401: '해야하는걸',
#   402: '중요할',
#   403: '따져요',
#   404: '결혼식',
#   405: '친거',
#   406: '종족',
#   407: '주전',
#   408: '잠겼어',
#   409: '무거워져',
#   410: '어떠셨어',
#   411: '없을거',
#   412: '아프네요',
#   413: '중요하게',
#   414: '안되고',
#   415: '인듯',
#   416: '자체',
#   417: '지워지지',
#   418: '예쁘더라',
#   419: '남았나',
#   420: '아니었을텐데',
#   421: '부담',
#   422: '잘해줘',
#   423: '바싹바싹',
#   424: '날림',
#   425: '귀찮아',
#   426: '정답',
#   427: '버림',
#   428: '그립겠어요',
#   429: '봇',
#   430: '취직',
#   431: '대비',
#   432: '허전할거라',
#   433: '마스크',
#   434: '되어가는데',
#   435: '감추는',
#   436: '서점',
#   437: '에너지',
#   438: '그립다고',
#   439: '죽으란',
#   440: '알려줘요',
#   441: '아닌',
#   442: '거둘',
#   443: '상치',
#   444: '카페',
#   445: '나누었길',
#   446: '자신만만하던게',
#   447: '마무리',
#   448: '괜찬',
#   449: '탓',
#   450: '놀고',
#   451: '자세히',
#   452: '때리는것도',
#   453: '안전하지',
#   454: '지내자',
#   455: '선톡',
#   456: '생리통',
#   457: '갑작스럽게',
#   458: '통보',
#   459: '맛',
#   460: '귀찮다',
#   461: '잃었었네',
#   462: '이뤄가길',
#   463: '울적하겠어요',
#   464: '소화',
#   465: '엊그제',
#   466: '싫더라고요',
#   467: '많아지죠',
#   468: '에서',
#   469: '살아라',
#   470: '예뻐지는',
#   471: '15일',
#   472: '불편하겠죠',
#   473: '행복해야',
#   474: '어려서',
#   475: '분양',
#   476: '두번째',
#   477: '제발',
#   478: '자야겠다',
#   479: '흐려지니까',
#   480: '알겠죠',
#   481: '미세먼지',
#   482: '아무렇지',
#   483: '꾼거',
#   484: '특히',
#   485: '너덜너덜해진',
#   486: '빠지셨군요',
#   487: '놈',
#   488: '잊기',
#   489: '참아야',
#   490: '되게',
#   491: '결핍',
#   492: '갚냐',
#   493: '될것',
#   494: '망가질테',
#   495: '친절한데',
#   496: '환장하겠어',
#   497: '올인',
#   498: '만나고싶다',
#   499: '가는',
#   500: '쓰인다고',
#   501: '많았죠',
#   502: '벌',
#   503: '어떨까',
#   504: '만나기만',
#   505: '보내시길',
#   506: '남은거랑',
#   507: '카풀',
#   508: '피곤하게',
#   509: '사다주면',
#   510: '길은',
#   511: '명품',
#   512: '모았다',
#   513: '짧아',
#   514: '어려워',
#   515: '남자친구',
#   516: '둔',
#   517: '돌아가야',
#   518: '일어나세요',
#   519: '찾아올거라',
#   520: '먹던게',
#   521: '더워',
#   522: '꿰매',
#   523: '도로',
#   524: '정신과',
#   525: '만은',
#   526: '가끔',
#   527: '봐주니까',
#   528: '안별',
#   529: '매달려서',
#   530: '정신',
#   531: '신혼여행',
#   532: '보내야',
#   533: '살았습니다',
#   534: '퇴치',
#   535: '지치게',
#   536: '내실텐데',
#   537: '그런대로',
#   538: '찢어지게',
#   539: '자니',
#   540: '가슴',
#   541: '붙여야겠다',
#   542: '세우지',
#   543: '목전',
#   544: '돌리면',
#   545: '안하내',
#   546: '식사',
#   547: '돌아올거',
#   548: '예민하면',
#   549: '피어싱',
#   550: 'jk',
#   551: '똑',
#   552: '진중한',
#   553: '자는',
#   554: '돌아간거',
#   555: '막혀',
#   556: '년놈',
#   557: '일어나',
#   558: '몰아서',
#   559: '싶다',
#   560: '흥미',
#   561: '이로',
#   562: '씰룩씰룩',
#   563: '좋네요',
#   564: '있을게',
#   565: '만큼은',
#   566: '맛있을',
#   567: '달',
#   568: '간단하지',
#   569: '여기는',
#   570: '녹차',
#   571: '챙겼나',
#   572: '샀어',
#   573: '먹었던게',
#   574: '리지',
#   575: '않을지도',
#   576: '미치겠네',
#   577: '싶어진',
#   578: '타긴',
#   579: '아껴',
#   580: '버려야',
#   581: '흘렀네',
#   582: '휴식',
#   583: '완벽한',
#   584: '힘내세',
#   585: '석',
#   586: '장단점',
#   587: '전의',
#   588: '샤워',
#   589: '받앗어',
#   590: '두려워',
#   591: '이냐에',
#   592: '유통',
#   593: '있니',
#   594: '주절거려',
#   595: '애기',
#   596: '괴롭다',
#   597: '근해',
#   598: '지나가다',
#   599: '막고싶은데',
#   600: '힘든거지',
#   601: '나왔으면',
#   602: '비슷한거',
#   603: '놓아줄까',
#   604: '아니에요',
#   605: '안되는지',
#   606: '휴학',
#   607: '발현',
#   608: '얻은',
#   609: '해주고싶은데',
#   610: '그러려니',
#   611: '야해서',
#   612: '북',
#   613: '모임이라면',
#   614: '먹게',
#   615: '가야겠지',
#   616: '복근',
#   617: '닥터',
#   618: '수없이',
#   619: '느낄',
#   620: '헤어지지',
#   621: '참고',
#   622: '끝냅니다',
#   623: '해어진지',
#   624: '이었으지도',
#   625: '절절',
#   626: '버리자',
#   627: '싶어',
#   628: '났습니다',
#   629: '입',
#   630: '배워도',
#   631: '연습',
#   632: '극적',
#   633: '그럴만',
#   634: '방학',
#   635: '클럽',
#   636: '입어도',
#   637: '됐어',
#   638: '경쟁자',
#   639: '잼',
#   640: '같습니다',
#   641: '발등',
#   642: '고수',
#   643: '꼈어',
#   644: '밝혀',
#   645: '알콩달콩',
#   646: '놀고만',
#   647: '꼬',
#   648: '나날',
#   649: '회원',
#   650: '제',
#   651: '우릴',
#   652: '물어보고',
#   653: '영역',
#   654: '얼떨떨할',
#   655: '먹방',
#   656: '쉬면서',
#   657: '미화',
#   658: '불안해요',
#   659: '두려운데',
#   660: '올랐다가',
#   661: '미소',
#   662: '헬스',
#   663: '주소',
#   664: '활동',
#   665: '이러면',
#   666: '일단',
#   667: '무한리필',
#   668: '기다려주세요',
#   669: '착하다고',
#   670: '무시',
#   671: '판도라',
#   672: '중요합니다',
#   673: '태어난다면',
#   674: '잊겠습니다',
#   675: '전화하는',
#   676: '사라짐',
#   677: '사귀려고',
#   678: '내렸나',
#   679: '안녕히',
#   680: '떠나야겠지',
#   681: '양궁',
#   682: '해보는',
#   683: '끓여',
#   684: '감싸주세요',
#   685: '편합니다',
#   686: '향기',
#   687: '헤어졋',
#   688: '여사',
#   689: '신입',
#   690: '불토',
#   691: '씹하면',
#   692: '오려나요',
#   693: '바꿀까',
#   694: '미친것',
#   695: '로봇',
#   696: '좋았어',
#   697: '쌓아주세요',
#   698: '꽃놀이',
#   699: '나죠',
#   700: '그랬지',
#   701: '차용',
#   702: '사귄',
#   703: '누락',
#   704: '장갑',
#   705: '없어졌다',
#   706: '사귀어',
#   707: '나이',
#   708: '쉬어도',
#   709: '되는줄',
#   710: '얼굴',
#   711: '또다른',
#   712: '콧물',
#   713: '푸르른',
#   714: '불행해도',
#   715: '썸이길',
#   716: '늦어요',
#   717: '공허하네',
#   718: '어린데',
#   719: '쉬마',
#   720: '달라지겠죠',
#   721: '옷장',
#   722: '이겠지요',
#   723: '할껄',
#   724: '아닌것인가',
#   725: '쌓이기',
#   726: '페친',
#   727: '전화왔어',
#   728: '짧지는',
#   729: '좋겠다고',
#   730: '하겠죠',
#   731: '찾기네요',
#   732: '있잖아',
#   733: '바빠도',
#   734: '거기',
#   735: '얇아',
#   736: '생길',
#   737: '좋아하면서도',
#   738: '제안',
#   739: '지치고',
#   740: '찔려',
#   741: '느껴',
#   742: '인스타그램',
#   743: '돌아가서',
#   744: '멈추고',
#   745: '만들어요',
#   746: '없어죠',
#   747: '이다',
#   748: '뒤통수',
#   749: '끊는',
#   750: '다가가고',
#   751: '반했어',
#   752: '소비',
#   753: '힘들겠다',
#   754: '만들어주는',
#   755: '하려고',
#   756: '붙자',
#   757: '되었는지',
#   758: '맞추는',
#   759: '괜찮은데',
#   760: '적극',
#   761: '예쁜',
#   762: '지내나',
#   763: '했군요',
#   764: '바뀌길',
#   765: '타야지',
#   766: '않네요',
#   767: '내려놔',
#   768: '띄길',
#   769: '하셨네요',
#   770: '필요한',
#   771: '엇갈림',
#   772: '괜찮길',
#   773: '맴',
#   774: '대학교',
#   775: '아들',
#   776: '팀워크',
#   777: '높아질',
#   778: '틀어도',
#   779: '끈이었어',
#   780: '연말',
#   781: '흐르는',
#   782: '보렴',
#   783: '생긴다',
#   784: '흔들지',
#   785: '싫어할',
#   786: '치여',
#   787: '심한데',
#   788: '열심히',
#   789: '붙여놓은',
#   790: '꾸리',
#   791: '할수록',
#   792: '코스터',
#   793: '중요성',
#   794: '간직',
#   795: '지친',
#   796: '무',
#   797: '지망',
#   798: '중요한건',
#   799: '피곤하신',
#   800: '채워',
#   801: '좋아한대',
#   802: '버렸나',
#   803: '골',
#   804: '생활용품',
#   805: '층간소음',
#   806: '헤어져도',
#   807: '성공했길',
#   808: '이미지',
#   809: '멀어진다는말',
#   810: '종종',
#   811: '패션',
#   812: '하냐',
#   813: '탄탄한',
#   814: '눈치',
#   815: '안되는군',
#   816: '식상하지',
#   817: '복잡하고',
#   818: '보러',
#   819: '잡념',
#   820: '끝나가니',
#   821: '괜찮아졌네',
#   822: '불안한',
#   823: '한꺼',
#   824: '희망이',
#   825: '그르친',
#   826: '생각나네요',
#   827: '좋겠지요',
#   828: '감싸',
#   829: '놀자',
#   830: '일어나자마자',
#   831: '잠겼는데',
#   832: '푸네',
#   833: '무관심한',
#   834: '건물',
#   835: '사겨야죠',
#   836: '기억나지',
#   837: '아까운데',
#   838: '기름',
#   839: '붙잡아',
#   840: '트집',
#   841: '복잡할',
#   842: '행복하지만은',
#   843: '끝낼까',
#   844: '먹어야',
#   845: '들어가세요',
#   846: '됐나',
#   847: '잊고싶다',
#   848: '드시지',
#   849: '행복하다는',
#   850: '성경',
#   851: '잘해주면',
#   852: '꼿',
#   853: '잘생겼어',
#   854: '걸다가',
#   855: '밀어야겠다',
#   856: '알았던',
#   857: '다신',
#   858: '이어지길',
#   859: '싫네',
#   860: '씌였나봐',
#   861: '포인트',
#   862: '만이',
#   863: '2일',
#   864: '들이',
#   865: '땡',
#   866: '법적',
#   867: '새사람',
#   868: '수상한데',
#   869: '온',
#   870: '기다렸는데',
#   871: '야근',
#   872: '취',
#   873: '끝냈는데',
#   874: '분들',
#   875: '게시',
#   876: '아물런',
#   877: '그럴게요',
#   878: '빈손',
#   879: '맴도',
#   880: '…',
#   881: '짜는거',
#   882: '받아',
#   883: '깍',
#   884: '잇었겠죠',
#   885: '잡길',
#   886: 'ㅎㅎ',
#   887: '무르팍',
#   888: '죄',
#   889: '됐군',
#   890: '오네여',
#   891: '교복',
#   892: '하고도',
#   893: '생겼더라',
#   894: '보고서',
#   895: '간단한',
#   896: '필요한거겠죠',
#   897: '의지',
#   898: '둘',
#   899: '세',
#   900: '오셨길',
#   901: '마시려고',
#   902: '까아',
#   903: '가벼워질거예요',
#   904: '좋아한다면',
#   905: '박치기',
#   906: '멋있는데',
#   907: '잘생겼어요',
#   908: '롤로',
#   909: '설쳤나',
#   910: '없을수록',
#   911: '오셨을까',
#   912: '온라인',
#   913: '살아가는',
#   914: '작아지곤',
#   915: '커지',
#   916: '씹어야겠다',
#   917: '워시',
#   918: '조가',
#   919: '으로서',
#   920: '코고',
#   921: '고작',
#   922: '힘들어져',
#   923: '애매하긴',
#   924: '모자라',
#   925: '부러',
#   926: '익숙해지는데는',
#   927: '샀다',
#   928: '변하는',
#   929: '않다면',
#   930: '단수',
#   931: '스쳐도',
#   932: '중',
#   933: '깐깐해',
#   934: '룩',
#   935: '세포',
#   936: '하겠어',
#   937: '규칙',
#   938: '시켜',
#   939: '배고프지',
#   940: '보았네',
#   941: '기분',
#   942: '달라지는게',
#   943: '쓰니까',
#   944: '버렸으면',
#   945: '머릿속',
#   946: '떨려서',
#   947: '되어주고',
#   948: '내는',
#   949: '됨',
#   950: '되다니',
#   951: '싸운',
#   952: '일어난',
#   953: '다니기',
#   954: '잡겠다는',
#   955: '마켓',
#   956: '밀어내도',
#   957: '콩깍지',
#   958: '이러고있는게',
#   959: '싫다고',
#   960: '떠나려',
#   961: '얼어',
#   962: '피곤하겠어요',
#   963: '들은',
#   964: '편이',
#   965: '친한데',
#   966: '매몰',
#   967: '비집',
#   968: '말렸어',
#   969: '여전히',
#   970: '이었다',
#   971: '되는',
#   972: '고독',
#   973: '전날',
#   974: '분식',
#   975: '6',
#   976: '돌까',
#   977: '쥐',
#   978: '꾸었어',
#   979: '아마',
#   980: '노메이크업',
#   981: '격일',
#   982: '하지말고',
#   983: '간지러',
#   984: '착한',
#   985: '떨리죠',
#   986: '깜깜',
#   987: '들',
#   988: '기능',
#   989: '닷',
#   990: '입어',
#   991: '어김없이',
#   992: '높나',
#   993: '크셨나요',
#   994: '환상',
#   995: '해야겠다',
#   996: '치매',
#   997: '만의',
#   998: '쳐다',
#   999: '싸우고',
#   ...},
#  'pad_symbol': '<PAD>',
#  'sos_symbol': '<SOS>',
#  'vocab_size': 12657,
#  'word2idx': {'<PAD>': 0,
#   '<SOS>': 1,
#   '<EOS>': 2,
#   '<UNK>': 3,
#   '괜찮았었는데': 4,
#   '최신': 5,
#   '받니': 6,
#   '어리석은': 7,
#   '남이었나': 8,
#   '우울하다': 9,
#   '곱씹지': 10,
#   '아프신': 11,
#   '참으면': 12,
#   '길게': 13,
#   '먹으러': 14,
#   '일까봐': 15,
#   '그럼': 16,
#   '보내는': 17,
#   '설사': 18,
#   '나와요': 19,
#   '솔직해서': 20,
#   '5': 21,
#   '이었을테니까': 22,
#   '걔': 23,
#   '현명하시군요': 24,
#   '멘탈': 25,
#   '읽는다': 26,
#   '떠보는': 27,
#   '털털': 28,
#   '처리': 29,
#   '탈까': 30,
#   '똑같이': 31,
#   '오해': 32,
#   '괜찮지만': 33,
#   '초면': 34,
#   '꾼': 35,
#   '쌓였네': 36,
#   '곱씹어도': 37,
#   '하셨어요': 38,
#   '동선': 39,
#   '보냈군요': 40,
#   '힘든고': 41,
#   '귀염둥': 42,
#   '상책': 43,
#   '청결한': 44,
#   '가르쳐': 45,
#   '회': 46,
#   '들도록': 47,
#   '대단한': 48,
#   '위로': 49,
#   '캐': 50,
#   '붙었대': 51,
#   '파마': 52,
#   '갔지': 53,
#   '글귀': 54,
#   '갈궈': 55,
#   '쏠': 56,
#   '힘든가요': 57,
#   '아껴주세요': 58,
#   '사과': 59,
#   '타는데': 60,
#   '비싸다': 61,
#   '사니': 62,
#   '400일': 63,
#   '소홀히': 64,
#   '당첨': 65,
#   '요긴': 66,
#   '싸는': 67,
#   '지내고': 68,
#   '멍하네': 69,
#   '쏟아지고': 70,
#   '궁금하니까': 71,
#   '설레게하는': 72,
#   '동갑': 73,
#   '부담스러': 74,
#   '풀': 75,
#   '하는구나': 76,
#   '사무칠': 77,
#   '와야': 78,
#   '수도': 79,
#   '해바라기': 80,
#   '부담스럽나': 81,
#   '태그': 82,
#   '날씨': 83,
#   '찾아가는건': 84,
#   '해서예요': 85,
#   '바뀔까': 86,
#   '맛있어': 87,
#   '첫날': 88,
#   '오려나': 89,
#   '신의': 90,
#   '코': 91,
#   '상메': 92,
#   '랑은': 93,
#   '후회': 94,
#   '땅': 95,
#   '부었어': 96,
#   '자르듯': 97,
#   '턱': 98,
#   '관문': 99,
#   '바람': 100,
#   '때매': 101,
#   '거짓': 102,
#   '보냈습니다': 103,
#   '우울하고': 104,
#   '보렵니': 105,
#   '필요할테니': 106,
#   '두꺼워': 107,
#   '아니지요': 108,
#   '했지만': 109,
#   '주제': 110,
#   '맞출까': 111,
#   '먹구': 112,
#   '해주고싶을': 113,
#   '공연': 114,
#   '맛없어': 115,
#   '떨리겠어요': 116,
#   '받는다고': 117,
#   '두려운게': 118,
#   '달라질까': 119,
#   '애매한': 120,
#   '가야겠죠': 121,
#   '영원했으면': 122,
#   '단답이나': 123,
#   '되었지만': 124,
#   '쿨하게': 125,
#   '원하는걸': 126,
#   '돌아와요': 127,
#   '난뒤': 128,
#   '큐피드': 129,
#   '떨어요': 130,
#   '감동': 131,
#   '믿으세요': 132,
#   '없애기': 133,
#   '있었겠어요': 134,
#   '느리겠죠': 135,
#   '솔직하고': 136,
#   '찢어지내': 137,
#   '반복': 138,
#   '맞추세요': 139,
#   '없네': 140,
#   '출근': 141,
#   '잃어버림': 142,
#   '아름답지': 143,
#   '간단하게': 144,
#   '자기애': 145,
#   '챙겼어': 146,
#   '간의': 147,
#   '호팬': 148,
#   '들어오네': 149,
#   '마침표': 150,
#   '갖춰서': 151,
#   '괜찮으면': 152,
#   '안좋겠지': 153,
#   '인가요': 154,
#   '뚫니는': 155,
#   '귀찮아서': 156,
#   '나오는': 157,
#   '컴백': 158,
#   '빌려': 159,
#   '없을거예요': 160,
#   '놓지': 161,
#   '변했다고': 162,
#   '넓으신': 163,
#   '서른': 164,
#   '가잖아': 165,
#   '용납': 166,
#   '보이스피싱': 167,
#   '끝났는데': 168,
#   '그러니': 169,
#   '줄었어': 170,
#   '달려있겠죠': 171,
#   '떠났으면': 172,
#   '짓게': 173,
#   '장벽': 174,
#   '도대체': 175,
#   '알바': 176,
#   '넣을': 177,
#   '부추기면': 178,
#   '지겠지': 179,
#   '가네': 180,
#   '트레이닝복': 181,
#   '삶속': 182,
#   '조심해야겠다': 183,
#   '보여준것': 184,
#   '재미있을': 185,
#   '없든': 186,
#   '스킨십': 187,
#   '명절': 188,
#   '재': 189,
#   '외로울까': 190,
#   '지나갔으면': 191,
#   '없죠': 192,
#   '일어났나': 193,
#   '더보': 194,
#   '추가': 195,
#   '아쉽지만': 196,
#   '이상해졌어': 197,
#   '떨어져': 198,
#   '일차': 199,
#   '유지': 200,
#   '잊혀질까': 201,
#   '일방': 202,
#   '화이트데이': 203,
#   '귀여워': 204,
#   '쓸쓸합니다': 205,
#   '좋으면서도': 206,
#   '심심': 207,
#   '넘': 208,
#   '겠지만': 209,
#   '하자고': 210,
#   '극혐': 211,
#   '말껄': 212,
#   '않은건': 213,
#   '나쁘겠어요': 214,
#   '째야': 215,
#   '나아지고': 216,
#   '아련하네요': 217,
#   '아니겠지요': 218,
#   '된다': 219,
#   '에서까지': 220,
#   '이기도': 221,
#   '야구장': 222,
#   '친절한': 223,
#   '꾹꾹': 224,
#   '인맥': 225,
#   '선택': 226,
#   '올거야': 227,
#   '커지거나': 228,
#   '광탈': 229,
#   '쉬셔야': 230,
#   '나타났을까요': 231,
#   '안좋아요': 232,
#   '농도': 233,
#   '실례': 234,
#   '지나고나면': 235,
#   '타냐고': 236,
#   '아련하기도': 237,
#   '독박': 238,
#   '무감각': 239,
#   '애석해요': 240,
#   '어때요': 241,
#   '위험하겠지': 242,
#   '잊어야겠지': 243,
#   '하다': 244,
#   '어리석게': 245,
#   '맞아서': 246,
#   '나가기도': 247,
#   '찾아야': 248,
#   '않아요': 249,
#   '양제': 250,
#   '온통': 251,
#   '이었길': 252,
#   '꾹': 253,
#   '동거': 254,
#   '확실하다면': 255,
#   '보는게': 256,
#   '한나': 257,
#   '본지': 258,
#   '달라져요': 259,
#   '코골': 260,
#   '씻기': 261,
#   '대하는게': 262,
#   '꽃': 263,
#   '김치볶음밥': 264,
#   '날거': 265,
#   '되나': 266,
#   '냉동': 267,
#   '해보시는건': 268,
#   '잊기로': 269,
#   '내서': 270,
#   '않습니다': 271,
#   '블랙데이': 272,
#   '생겼나': 273,
#   '42일': 274,
#   '편해': 275,
#   '놓으세요': 276,
#   '않지요': 277,
#   '라는': 278,
#   '나그네': 279,
#   '육아': 280,
#   '마셔야겠다': 281,
#   '고충': 282,
#   '구질': 283,
#   '스타벅스': 284,
#   '비싸겠지': 285,
#   '안고': 286,
#   '넓어': 287,
#   '사오세요': 288,
#   '해야하는': 289,
#   '느껴지지': 290,
#   '하고야': 291,
#   'ㅜ': 292,
#   '신혼집': 293,
#   '스타': 294,
#   '보입니다': 295,
#   '흘려도': 296,
#   '여러': 297,
#   '보여줘야': 298,
#   '가미': 299,
#   '가리세요': 300,
#   '데': 301,
#   '쓰담': 302,
#   '힘내라는': 303,
#   '쳐다봄': 304,
#   '불효': 305,
#   '돌릴': 306,
#   '넘었는데도': 307,
#   '명언': 308,
#   '바라던': 309,
#   '취뽀': 310,
#   '받아들이': 311,
#   '벌주어야': 312,
#   '꽃다발': 313,
#   '남으면': 314,
#   '대기네요': 315,
#   '당했어': 316,
#   '자격지심': 317,
#   '달렸나': 318,
#   '키워': 319,
#   '찍고': 320,
#   '시켜야': 321,
#   '보람': 322,
#   '한정식': 323,
#   '알아차리지': 324,
#   '힘들줄': 325,
#   '많을까요': 326,
#   '갔을까': 327,
#   '태': 328,
#   '이루길': 329,
#   '전과': 330,
#   '듣고싶어': 331,
#   '저녁': 332,
#   '만났었지': 333,
#   '느껴지겠어요': 334,
#   '솔솔': 335,
#   '걸레질': 336,
#   '껴야겠어': 337,
#   '드라이': 338,
#   '질려하려면': 339,
#   '하죠': 340,
#   '헌신': 341,
#   '있고싶다는': 342,
#   '해라고': 343,
#   '다크서클': 344,
#   '쌓여가': 345,
#   '망설여지나': 346,
#   '갈림': 347,
#   '봤으면': 348,
#   '기대하면서': 349,
#   '사귈래': 350,
#   '끝': 351,
#   '부부': 352,
#   '가만히': 353,
#   '애틋한': 354,
#   '겟': 355,
#   '생판': 356,
#   '무사히': 357,
#   '건강하게': 358,
#   '쓴': 359,
#   '쉬운게': 360,
#   '화난': 361,
#   '많았어요': 362,
#   '다정다감한': 363,
#   '감은': 364,
#   '지나가지': 365,
#   '낀': 366,
#   '갈았어': 367,
#   '의문': 368,
#   '심하긴': 369,
#   '넘고': 370,
#   '갑작스러웠을테니까': 371,
#   '살아야죠': 372,
#   '익숙해졌나': 373,
#   '좋아하게': 374,
#   '쫙': 375,
#   '붙이세요': 376,
#   '할줄이야': 377,
#   '분하고': 378,
#   '헤어진': 379,
#   '고고': 380,
#   '다시는': 381,
#   '짜증남': 382,
#   '갠톡': 383,
#   '돼야지': 384,
#   '받아들여야': 385,
#   '만날거야': 386,
#   '됐던': 387,
#   '라나': 388,
#   '두절': 389,
#   '님들': 390,
#   '형': 391,
#   '퐈': 392,
#   '죽겠어': 393,
#   '바랐지만': 394,
#   '싸늘해': 395,
#   '앉는': 396,
#   '싶었나': 397,
#   '쓰디': 398,
#   '잊든': 399,
#   '고시원': 400,
#   '해야하는걸': 401,
#   '중요할': 402,
#   '따져요': 403,
#   '결혼식': 404,
#   '친거': 405,
#   '종족': 406,
#   '주전': 407,
#   '잠겼어': 408,
#   '무거워져': 409,
#   '어떠셨어': 410,
#   '없을거': 411,
#   '아프네요': 412,
#   '중요하게': 413,
#   '안되고': 414,
#   '인듯': 415,
#   '자체': 416,
#   '지워지지': 417,
#   '예쁘더라': 418,
#   '남았나': 419,
#   '아니었을텐데': 420,
#   '부담': 421,
#   '잘해줘': 422,
#   '바싹바싹': 423,
#   '날림': 424,
#   '귀찮아': 425,
#   '정답': 426,
#   '버림': 427,
#   '그립겠어요': 428,
#   '봇': 429,
#   '취직': 430,
#   '대비': 431,
#   '허전할거라': 432,
#   '마스크': 433,
#   '되어가는데': 434,
#   '감추는': 435,
#   '서점': 436,
#   '에너지': 437,
#   '그립다고': 438,
#   '죽으란': 439,
#   '알려줘요': 440,
#   '아닌': 441,
#   '거둘': 442,
#   '상치': 443,
#   '카페': 444,
#   '나누었길': 445,
#   '자신만만하던게': 446,
#   '마무리': 447,
#   '괜찬': 448,
#   '탓': 449,
#   '놀고': 450,
#   '자세히': 451,
#   '때리는것도': 452,
#   '안전하지': 453,
#   '지내자': 454,
#   '선톡': 455,
#   '생리통': 456,
#   '갑작스럽게': 457,
#   '통보': 458,
#   '맛': 459,
#   '귀찮다': 460,
#   '잃었었네': 461,
#   '이뤄가길': 462,
#   '울적하겠어요': 463,
#   '소화': 464,
#   '엊그제': 465,
#   '싫더라고요': 466,
#   '많아지죠': 467,
#   '에서': 468,
#   '살아라': 469,
#   '예뻐지는': 470,
#   '15일': 471,
#   '불편하겠죠': 472,
#   '행복해야': 473,
#   '어려서': 474,
#   '분양': 475,
#   '두번째': 476,
#   '제발': 477,
#   '자야겠다': 478,
#   '흐려지니까': 479,
#   '알겠죠': 480,
#   '미세먼지': 481,
#   '아무렇지': 482,
#   '꾼거': 483,
#   '특히': 484,
#   '너덜너덜해진': 485,
#   '빠지셨군요': 486,
#   '놈': 487,
#   '잊기': 488,
#   '참아야': 489,
#   '되게': 490,
#   '결핍': 491,
#   '갚냐': 492,
#   '될것': 493,
#   '망가질테': 494,
#   '친절한데': 495,
#   '환장하겠어': 496,
#   '올인': 497,
#   '만나고싶다': 498,
#   '가는': 499,
#   '쓰인다고': 500,
#   '많았죠': 501,
#   '벌': 502,
#   '어떨까': 503,
#   '만나기만': 504,
#   '보내시길': 505,
#   '남은거랑': 506,
#   '카풀': 507,
#   '피곤하게': 508,
#   '사다주면': 509,
#   '길은': 510,
#   '명품': 511,
#   '모았다': 512,
#   '짧아': 513,
#   '어려워': 514,
#   '남자친구': 515,
#   '둔': 516,
#   '돌아가야': 517,
#   '일어나세요': 518,
#   '찾아올거라': 519,
#   '먹던게': 520,
#   '더워': 521,
#   '꿰매': 522,
#   '도로': 523,
#   '정신과': 524,
#   '만은': 525,
#   '가끔': 526,
#   '봐주니까': 527,
#   '안별': 528,
#   '매달려서': 529,
#   '정신': 530,
#   '신혼여행': 531,
#   '보내야': 532,
#   '살았습니다': 533,
#   '퇴치': 534,
#   '지치게': 535,
#   '내실텐데': 536,
#   '그런대로': 537,
#   '찢어지게': 538,
#   '자니': 539,
#   '가슴': 540,
#   '붙여야겠다': 541,
#   '세우지': 542,
#   '목전': 543,
#   '돌리면': 544,
#   '안하내': 545,
#   '식사': 546,
#   '돌아올거': 547,
#   '예민하면': 548,
#   '피어싱': 549,
#   'jk': 550,
#   '똑': 551,
#   '진중한': 552,
#   '자는': 553,
#   '돌아간거': 554,
#   '막혀': 555,
#   '년놈': 556,
#   '일어나': 557,
#   '몰아서': 558,
#   '싶다': 559,
#   '흥미': 560,
#   '이로': 561,
#   '씰룩씰룩': 562,
#   '좋네요': 563,
#   '있을게': 564,
#   '만큼은': 565,
#   '맛있을': 566,
#   '달': 567,
#   '간단하지': 568,
#   '여기는': 569,
#   '녹차': 570,
#   '챙겼나': 571,
#   '샀어': 572,
#   '먹었던게': 573,
#   '리지': 574,
#   '않을지도': 575,
#   '미치겠네': 576,
#   '싶어진': 577,
#   '타긴': 578,
#   '아껴': 579,
#   '버려야': 580,
#   '흘렀네': 581,
#   '휴식': 582,
#   '완벽한': 583,
#   '힘내세': 584,
#   '석': 585,
#   '장단점': 586,
#   '전의': 587,
#   '샤워': 588,
#   '받앗어': 589,
#   '두려워': 590,
#   '이냐에': 591,
#   '유통': 592,
#   '있니': 593,
#   '주절거려': 594,
#   '애기': 595,
#   '괴롭다': 596,
#   '근해': 597,
#   '지나가다': 598,
#   '막고싶은데': 599,
#   '힘든거지': 600,
#   '나왔으면': 601,
#   '비슷한거': 602,
#   '놓아줄까': 603,
#   '아니에요': 604,
#   '안되는지': 605,
#   '휴학': 606,
#   '발현': 607,
#   '얻은': 608,
#   '해주고싶은데': 609,
#   '그러려니': 610,
#   '야해서': 611,
#   '북': 612,
#   '모임이라면': 613,
#   '먹게': 614,
#   '가야겠지': 615,
#   '복근': 616,
#   '닥터': 617,
#   '수없이': 618,
#   '느낄': 619,
#   '헤어지지': 620,
#   '참고': 621,
#   '끝냅니다': 622,
#   '해어진지': 623,
#   '이었으지도': 624,
#   '절절': 625,
#   '버리자': 626,
#   '싶어': 627,
#   '났습니다': 628,
#   '입': 629,
#   '배워도': 630,
#   '연습': 631,
#   '극적': 632,
#   '그럴만': 633,
#   '방학': 634,
#   '클럽': 635,
#   '입어도': 636,
#   '됐어': 637,
#   '경쟁자': 638,
#   '잼': 639,
#   '같습니다': 640,
#   '발등': 641,
#   '고수': 642,
#   '꼈어': 643,
#   '밝혀': 644,
#   '알콩달콩': 645,
#   '놀고만': 646,
#   '꼬': 647,
#   '나날': 648,
#   '회원': 649,
#   '제': 650,
#   '우릴': 651,
#   '물어보고': 652,
#   '영역': 653,
#   '얼떨떨할': 654,
#   '먹방': 655,
#   '쉬면서': 656,
#   '미화': 657,
#   '불안해요': 658,
#   '두려운데': 659,
#   '올랐다가': 660,
#   '미소': 661,
#   '헬스': 662,
#   '주소': 663,
#   '활동': 664,
#   '이러면': 665,
#   '일단': 666,
#   '무한리필': 667,
#   '기다려주세요': 668,
#   '착하다고': 669,
#   '무시': 670,
#   '판도라': 671,
#   '중요합니다': 672,
#   '태어난다면': 673,
#   '잊겠습니다': 674,
#   '전화하는': 675,
#   '사라짐': 676,
#   '사귀려고': 677,
#   '내렸나': 678,
#   '안녕히': 679,
#   '떠나야겠지': 680,
#   '양궁': 681,
#   '해보는': 682,
#   '끓여': 683,
#   '감싸주세요': 684,
#   '편합니다': 685,
#   '향기': 686,
#   '헤어졋': 687,
#   '여사': 688,
#   '신입': 689,
#   '불토': 690,
#   '씹하면': 691,
#   '오려나요': 692,
#   '바꿀까': 693,
#   '미친것': 694,
#   '로봇': 695,
#   '좋았어': 696,
#   '쌓아주세요': 697,
#   '꽃놀이': 698,
#   '나죠': 699,
#   '그랬지': 700,
#   '차용': 701,
#   '사귄': 702,
#   '누락': 703,
#   '장갑': 704,
#   '없어졌다': 705,
#   '사귀어': 706,
#   '나이': 707,
#   '쉬어도': 708,
#   '되는줄': 709,
#   '얼굴': 710,
#   '또다른': 711,
#   '콧물': 712,
#   '푸르른': 713,
#   '불행해도': 714,
#   '썸이길': 715,
#   '늦어요': 716,
#   '공허하네': 717,
#   '어린데': 718,
#   '쉬마': 719,
#   '달라지겠죠': 720,
#   '옷장': 721,
#   '이겠지요': 722,
#   '할껄': 723,
#   '아닌것인가': 724,
#   '쌓이기': 725,
#   '페친': 726,
#   '전화왔어': 727,
#   '짧지는': 728,
#   '좋겠다고': 729,
#   '하겠죠': 730,
#   '찾기네요': 731,
#   '있잖아': 732,
#   '바빠도': 733,
#   '거기': 734,
#   '얇아': 735,
#   '생길': 736,
#   '좋아하면서도': 737,
#   '제안': 738,
#   '지치고': 739,
#   '찔려': 740,
#   '느껴': 741,
#   '인스타그램': 742,
#   '돌아가서': 743,
#   '멈추고': 744,
#   '만들어요': 745,
#   '없어죠': 746,
#   '이다': 747,
#   '뒤통수': 748,
#   '끊는': 749,
#   '다가가고': 750,
#   '반했어': 751,
#   '소비': 752,
#   '힘들겠다': 753,
#   '만들어주는': 754,
#   '하려고': 755,
#   '붙자': 756,
#   '되었는지': 757,
#   '맞추는': 758,
#   '괜찮은데': 759,
#   '적극': 760,
#   '예쁜': 761,
#   '지내나': 762,
#   '했군요': 763,
#   '바뀌길': 764,
#   '타야지': 765,
#   '않네요': 766,
#   '내려놔': 767,
#   '띄길': 768,
#   '하셨네요': 769,
#   '필요한': 770,
#   '엇갈림': 771,
#   '괜찮길': 772,
#   '맴': 773,
#   '대학교': 774,
#   '아들': 775,
#   '팀워크': 776,
#   '높아질': 777,
#   '틀어도': 778,
#   '끈이었어': 779,
#   '연말': 780,
#   '흐르는': 781,
#   '보렴': 782,
#   '생긴다': 783,
#   '흔들지': 784,
#   '싫어할': 785,
#   '치여': 786,
#   '심한데': 787,
#   '열심히': 788,
#   '붙여놓은': 789,
#   '꾸리': 790,
#   '할수록': 791,
#   '코스터': 792,
#   '중요성': 793,
#   '간직': 794,
#   '지친': 795,
#   '무': 796,
#   '지망': 797,
#   '중요한건': 798,
#   '피곤하신': 799,
#   '채워': 800,
#   '좋아한대': 801,
#   '버렸나': 802,
#   '골': 803,
#   '생활용품': 804,
#   '층간소음': 805,
#   '헤어져도': 806,
#   '성공했길': 807,
#   '이미지': 808,
#   '멀어진다는말': 809,
#   '종종': 810,
#   '패션': 811,
#   '하냐': 812,
#   '탄탄한': 813,
#   '눈치': 814,
#   '안되는군': 815,
#   '식상하지': 816,
#   '복잡하고': 817,
#   '보러': 818,
#   '잡념': 819,
#   '끝나가니': 820,
#   '괜찮아졌네': 821,
#   '불안한': 822,
#   '한꺼': 823,
#   '희망이': 824,
#   '그르친': 825,
#   '생각나네요': 826,
#   '좋겠지요': 827,
#   '감싸': 828,
#   '놀자': 829,
#   '일어나자마자': 830,
#   '잠겼는데': 831,
#   '푸네': 832,
#   '무관심한': 833,
#   '건물': 834,
#   '사겨야죠': 835,
#   '기억나지': 836,
#   '아까운데': 837,
#   '기름': 838,
#   '붙잡아': 839,
#   '트집': 840,
#   '복잡할': 841,
#   '행복하지만은': 842,
#   '끝낼까': 843,
#   '먹어야': 844,
#   '들어가세요': 845,
#   '됐나': 846,
#   '잊고싶다': 847,
#   '드시지': 848,
#   '행복하다는': 849,
#   '성경': 850,
#   '잘해주면': 851,
#   '꼿': 852,
#   '잘생겼어': 853,
#   '걸다가': 854,
#   '밀어야겠다': 855,
#   '알았던': 856,
#   '다신': 857,
#   '이어지길': 858,
#   '싫네': 859,
#   '씌였나봐': 860,
#   '포인트': 861,
#   '만이': 862,
#   '2일': 863,
#   '들이': 864,
#   '땡': 865,
#   '법적': 866,
#   '새사람': 867,
#   '수상한데': 868,
#   '온': 869,
#   '기다렸는데': 870,
#   '야근': 871,
#   '취': 872,
#   '끝냈는데': 873,
#   '분들': 874,
#   '게시': 875,
#   '아물런': 876,
#   '그럴게요': 877,
#   '빈손': 878,
#   '맴도': 879,
#   '…': 880,
#   '짜는거': 881,
#   '받아': 882,
#   '깍': 883,
#   '잇었겠죠': 884,
#   '잡길': 885,
#   'ㅎㅎ': 886,
#   '무르팍': 887,
#   '죄': 888,
#   '됐군': 889,
#   '오네여': 890,
#   '교복': 891,
#   '하고도': 892,
#   '생겼더라': 893,
#   '보고서': 894,
#   '간단한': 895,
#   '필요한거겠죠': 896,
#   '의지': 897,
#   '둘': 898,
#   '세': 899,
#   '오셨길': 900,
#   '마시려고': 901,
#   '까아': 902,
#   '가벼워질거예요': 903,
#   '좋아한다면': 904,
#   '박치기': 905,
#   '멋있는데': 906,
#   '잘생겼어요': 907,
#   '롤로': 908,
#   '설쳤나': 909,
#   '없을수록': 910,
#   '오셨을까': 911,
#   '온라인': 912,
#   '살아가는': 913,
#   '작아지곤': 914,
#   '커지': 915,
#   '씹어야겠다': 916,
#   '워시': 917,
#   '조가': 918,
#   '으로서': 919,
#   '코고': 920,
#   '고작': 921,
#   '힘들어져': 922,
#   '애매하긴': 923,
#   '모자라': 924,
#   '부러': 925,
#   '익숙해지는데는': 926,
#   '샀다': 927,
#   '변하는': 928,
#   '않다면': 929,
#   '단수': 930,
#   '스쳐도': 931,
#   '중': 932,
#   '깐깐해': 933,
#   '룩': 934,
#   '세포': 935,
#   '하겠어': 936,
#   '규칙': 937,
#   '시켜': 938,
#   '배고프지': 939,
#   '보았네': 940,
#   '기분': 941,
#   '달라지는게': 942,
#   '쓰니까': 943,
#   '버렸으면': 944,
#   '머릿속': 945,
#   '떨려서': 946,
#   '되어주고': 947,
#   '내는': 948,
#   '됨': 949,
#   '되다니': 950,
#   '싸운': 951,
#   '일어난': 952,
#   '다니기': 953,
#   '잡겠다는': 954,
#   '마켓': 955,
#   '밀어내도': 956,
#   '콩깍지': 957,
#   '이러고있는게': 958,
#   '싫다고': 959,
#   '떠나려': 960,
#   '얼어': 961,
#   '피곤하겠어요': 962,
#   '들은': 963,
#   '편이': 964,
#   '친한데': 965,
#   '매몰': 966,
#   '비집': 967,
#   '말렸어': 968,
#   '여전히': 969,
#   '이었다': 970,
#   '되는': 971,
#   '고독': 972,
#   '전날': 973,
#   '분식': 974,
#   '6': 975,
#   '돌까': 976,
#   '쥐': 977,
#   '꾸었어': 978,
#   '아마': 979,
#   '노메이크업': 980,
#   '격일': 981,
#   '하지말고': 982,
#   '간지러': 983,
#   '착한': 984,
#   '떨리죠': 985,
#   '깜깜': 986,
#   '들': 987,
#   '기능': 988,
#   '닷': 989,
#   '입어': 990,
#   '어김없이': 991,
#   '높나': 992,
#   '크셨나요': 993,
#   '환상': 994,
#   '해야겠다': 995,
#   '치매': 996,
#   '만의': 997,
#   '쳐다': 998,
#   '싸우고': 999,
#   ...}}

# %%
DATA_IN_PATH = './data_in/'
TRAIN_INPUTS = 'train_inupts.npy'
TRAIN_OUTPUTS = 'train_outputs.npy'
TRAIN_TARGETS = 'train_targets.npy'
DATA_CONFIG = 'data_configs.json'

np.save(open(DATA_IN_PATH + TRAIN_INPUTS, 'wb'), index_enc_inputs)
np.save(open(DATA_IN_PATH + TRAIN_OUTPUTS, 'wb'), index_dec_inputs)
np.save(open(DATA_IN_PATH + TRAIN_TARGETS, 'wb'), index_dec_targets)


json.dump(data_config, open(DATA_IN_PATH + DATA_CONFIG, 'w'))

# %%
# !cp -r data_in/ '/content/drive/MyDrive/'
